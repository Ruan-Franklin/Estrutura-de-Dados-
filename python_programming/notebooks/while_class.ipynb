# %%
numero = 0
while numero <= 5:
    print("Esse é o valor do número agora", numero)
    numero+=1
print("Acabou o laço")
print("O laço terminou quando o n´umero chegou em", numero)
# Out:
# Esse é o valor do número agora 0
# Esse é o valor do número agora 1
# Esse é o valor do número agora 2
# Esse é o valor do número agora 3
# Esse é o valor do número agora 4
# Esse é o valor do número agora 5
# Acabou o laço
# O laço terminou quando o n´umero chegou em 6

# %%
numero = 5
while numero >= 0:
    print("Esse é o valor do número agora", numero)
    numero-=1
# Out:
# Esse é o valor do número agora 5
# Esse é o valor do número agora 4
# Esse é o valor do número agora 3
# Esse é o valor do número agora 2
# Esse é o valor do número agora 1
# Esse é o valor do número agora 0

# %%
soma = 0
numero = 1
while(numero <=15):
    numero+=1
    soma = soma + numero

print("A soma dos números de 1 a 15 é:", soma)
# Out:
# A soma dos números de 1 a 15 é: 135

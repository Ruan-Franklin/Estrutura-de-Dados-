# %%
print("Teste")
# Out:
# Teste

# %%
for i in range (0, 5):
    print("Esse é o i", i)
    print("------------")
    for j in range (0, 2):
        print(" Esse é o j ", j)
# Out:
# Esse é o i 0
# ------------
#  Esse é o j  0
#  Esse é o j  1
# Esse é o i 1
# ------------
#  Esse é o j  0
#  Esse é o j  1
# Esse é o i 2
# ------------
#  Esse é o j  0
#  Esse é o j  1
# Esse é o i 3
# ------------
#  Esse é o j  0
#  Esse é o j  1
# Esse é o i 4
# ------------
#  Esse é o j  0
#  Esse é o j  1

# %% [markdown]
# # Exercício 1
#
# ```
# Lista: Crie uma estrutura de repetição para fazer a leitura de 5 números inteiros e os armazene dentro de uma lista. Após a leitura, crie outra estrutura de repetição para somar todos os valores digitados
# ```

# %%
lista = []
soma = 0
while(len(lista) < 5):
    num = int(input("Digite um número: "))
    lista.append(num)
    soma += num
print("A soma dos números é: ", soma)
# Out:
# A soma dos números é:  15

# %% [markdown]
# ## Exercício 2
#
# ```
#
# Dicionário: Crie um dicionário para armazenar o nome e a nota de 3 alunos, fazendo a leitura dos valores por meio de uma estrutura de repetição. Depois, crie uma nova estrutura de repetição para somar todas as notas e retornar a média
#
# ```

# %%
def compute_statistics(data):
    n = len(data)
    mean = sum(data) / n
    sorted_data = sorted(data)
    median = (sorted_data[n // 2] if n % 2 == 1 else
              (sorted_data[n // 2 - 1] + sorted_data[n // 2]) / 2)
    variance = sum((x - mean) ** 2 for x in data) / n
    std_dev = variance ** 0.5
    return mean, median, variance, std_dev

data = [10, 20, 30, 40, 50]
mean, median, variance, std_dev = compute_statistics(data)
print(f"Mean: {mean}, Median: {median}, Variance: {variance}, Std Dev: {std_dev}")
# Out:
# Mean: 30.0, Median: 30, Variance: 200.0, Std Dev: 14.142135623730951
